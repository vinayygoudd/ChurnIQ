# %% [markdown]
# # Exploratory Analysis
# Run the reusable EDA module with `python -m src.analysis.eda`. This notebook intentionally does not contain fabricated metrics.

# %%
from src.data.loader import load_raw
from src.data.preprocessing import clean_frame
df=clean_frame(load_raw())
df.head()
